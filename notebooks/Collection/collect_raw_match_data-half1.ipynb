# %%
# !pip install git+https://github.com/seraphli/od-python.git
# Out:
# Collecting git+https://github.com/seraphli/od-python.git
#   Cloning https://github.com/seraphli/od-python.git to /tmp/pip-req-build-tgj_hosv
# Requirement already satisfied (use --upgrade to upgrade): od-python==1.0.2 from git+https://github.com/seraphli/od-python.git in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages
# Requirement already satisfied: urllib3>=1.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from od-python==1.0.2) (1.23)
# Requirement already satisfied: six>=1.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from od-python==1.0.2) (1.11.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from od-python==1.0.2) (2019.6.16)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from od-python==1.0.2) (2.7.3)
# Building wheels for collected packages: od-python
#   Running setup.py bdist_wheel for od-python ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pdfog26k/wheels/96/a0/9d/73ecc0fedd17a4cb6134556ad3c0386645657647205cc7062e
# Successfully built od-python
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from __future__ import print_function
import time
import od_python
from od_python.rest import ApiException
from pprint import pprint

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import math
from statistics import mean, stdev
import re

# %%
pro_ids = pd.read_csv("https://dota-match-ids.s3.amazonaws.com/pro_matches.txt", 
                         header=None, names=["match_id"])
pro_ids_first_half = pro_ids[:35000]
print(pro_ids_first_half.shape)
# Out:
# (35000, 1)

# %%
pro_ids_first_half.head()
# Out:
#      match_id
# 0  5108885702
# 1  5108800438
# 2  5108735167
# 3  5108711156
# 4  5108703089

# %%
current_bound = 1000
pro_ids_first_half_cur = pro_ids_first_half[:1000]

# %%
def get_matches(match_list):
    # TEAMFIGHTS AND PLAYER DATA NOT COLLECTED HERE
    m_id = []
    d_bar_stat = []
    r_bar_stat = []
    cluster = []
    cosmet = []
    d_score = []
    draft_time = []
    duration = []
    eng = []
    f_blood = []
    g_mode = []
    h_players = []
    l_id = []
    lob_type = []
    match_seq_num = []
    objectives = []
    picks_bans = []
    r_gold_adv = []
    r_score = []
    r_win = []
    r_xp_adv = []
    s_time = []
    d_tow_stat = []
    r_tow_stat = []
    ver = []
    s_id = []
    s_type = []
    r_team = []
    d_team = []
    league = []
    skill = []
    patch = []
    region = []
    throw = []
    loss = []    

    match_api = od_python.MatchesApi()
    counter = 0

    for match in match_list:
        try:
            if counter > 40:
                time.sleep(90)
                counter = 0
                print(match)
            
            api_response = match_api.matches_match_id_get(match)
            counter = counter + 1
            m_id.append(api_response.match_id)
            d_bar_stat.append(api_response.barracks_status_dire)
            r_bar_stat.append(api_response.barracks_status_radiant)
            cluster.append(api_response.cluster)
            cosmet.append(api_response.cosmetics)
            d_score.append(api_response.dire_score)
            draft_time.append(api_response.draft_timings)
            duration.append(api_response.duration)
            eng.append(api_response.engine)
            f_blood.append(api_response.first_blood_time)
            g_mode.append(api_response.game_mode)
            h_players.append(api_response.human_players)
            l_id.append(api_response.leagueid)
            lob_type.append(api_response.lobby_type)
            match_seq_num.append(api_response.match_seq_num)
            objectives.append(api_response.objectives)
            picks_bans.append(api_response.picks_bans)
            r_gold_adv.append(api_response.radiant_gold_adv)
            r_score.append(api_response.radiant_score)
            r_win.append(api_response.radiant_win)
            r_xp_adv.append(api_response.radiant_xp_adv)
            s_time.append(api_response.start_time)
            d_tow_stat.append(api_response.tower_status_dire)
            r_tow_stat.append(api_response.tower_status_radiant)
            ver.append(api_response.version)
            s_id.append(api_response.series_id)
            s_type.append(api_response.series_type)
            r_team.append(api_response.radiant_team)
            d_team.append(api_response.dire_team)
            league.append(api_response.league)
            skill.append(api_response.skill)
            patch.append(api_response.patch)
            region.append(api_response.region)
            throw.append(api_response.throw)
            loss.append(api_response.loss)

        except ApiException as e:
            print("Exception when calling MatchesAPI->matches_get: %s\n" % e)
            match_id = 0
               
    data_dict = {
        "match_id": m_id, "barracks_status_dire":d_bar_stat, "barracks_status_radiant": r_bar_stat,
        "cluster": cluster, "cosmetics": cosmet, "dire_score":d_score, "draft_timings": draft_time,
        "duration": duration, "engine": eng, "first_blood_time": f_blood, "game_mode": g_mode,
        "human_players": h_players, "leagueid": l_id, "lobby_type": lob_type, "match_seq_num": match_seq_num,
        "objectives": objectives, "picks_bans": picks_bans, "radiant_gold_adv": r_gold_adv, "radiant_score": r_score,
        "radiant_win": r_win, "radiant_xp_adv": r_xp_adv, "start_time": s_time, "tower_status_dire": d_tow_stat,
        "tower_status_radiant": r_tow_stat, "version": ver, "series_id": s_id, "series_type": s_type, 
        "radiant_team": r_team, "dire_team": d_team, "league": league, "skill": skill, "patch": patch, "region": region,
        "throw": throw, "loss": loss   
    }
    
    return data_dict

# %%
prof_match_data = get_matches(pro_ids_first_half_cur["match_id"])
df_pro_first_half = pd.DataFrame(data = prof_match_data)
print(df_pro_first_half.shape)
current_bound = current_bound + 1000
while current_bound <= len(pro_ids_first_half):
    pro_ids_first_half_cur = pro_ids_first_half[current_bound - 999 : current_bound]
    prof_match_data = get_matches(pro_ids_first_half_cur["match_id"])
    df_pro_cur = pd.DataFrame(data = prof_match_data)
    print(df_pro_cur.shape)
    df_pro_first_half = df_pro_first_half.append(df_pro_cur)
    print(df_pro_first_half.shape)
    test_bound = current_bound + 1000
    if test_bound > len(pro_ids_first_half):
        test_bound = len(pro_ids_first_half)
        pro_ids_first_half_cur = pro_ids_first_half[current_bound + 1 : test_bound]
        prof_match_data = get_matches(pro_ids_first_half_cur["match_id"])
        df_pro_cur = pd.DataFrame(data = prof_match_data)
        print(df_pro_cur.shape)
        df_pro_first_half = df_pro_first_half.append(df_pro_cur)
        print(df_pro_first_half.shape)
        break
    else:
        current_bound = test_bound
# Out:
# 5108313263
# 5107863038
# 5107443120
# 5107213614
# 5106363876
# 5105488247
# 5104142897
# 5103273780
# 5102571522
# 5101465913
# 5100291690
# 5099177071
# 5098779731
# 5098621216
# 5098360295
# 5097980085
# 5097669789
# 5097334101
# 5097029352
# 5096847882
# 5096598333
# 5096312245
# 5096100620
# 5095994101
# (1000, 35)
# 5094821020
# 5092760706
# 5090590453
# 5088982125
# 5087798751
# 5086709578
# 5085930731
# 5084512030
# 5083191641
# 5082505918
# 5081653267
# 5080629141
# 5079097109
# 5077858700
# 5077041861
# 5076180682
# 5075203836
# 5074473983
# 5073833797
# 5072722827
# 5071467261
# 5070201454
# 5068987720
# 5067926628
# (999, 35)
# (1999, 35)
# 5066031980
# 5065305960
# 5063592374
# 5062245048
# 5060888811
# 5058931598
# 5058131204
# 5057770540
# 5057290939
# 5056585340
# 5056220483
# 5055835146
# 5055420548
# 5054425764
# 5052077838
# 5050425050
# 5049731847
# 5047691964
# 5046683750
SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-126', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99dda97ded73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-127', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99ddf9cfed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-128', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99de4a3aed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-129', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99de9aabed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-130', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99dedb40ed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-131', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99df2bc1ed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-132', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99dfbc7fed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-133', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99e00ceded73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-134', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99e04d97ed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-135', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99e09e0ded73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-136', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99e0ee6bed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# Exception when calling MatchesAPI->matches_get: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'Date': 'Mon, 18 Nov 2019 17:17:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '31', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd05f59ad7e5bec2fa3e7178bd5f626571574097479; expires=Tue, 17-Nov-20 17:17:59 GMT; path=/; domain=.opendota.com; HttpOnly; Secure', 'X-Powered-By': 'Express', 'X-Rate-Limit-Remaining-Minute': '-137', 'X-IP-Address': '52.52.190.187', 'X-Rate-Limit-Remaining-Month': '19707', 'ETag': 'W/"1f-VmiKueY7P/iwN4d+xUresnC25/U"', 'Vary': 'Accept-Encoding', 'Via': '1.1 google', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '537b99e17f51ed73-SJC'})
# HTTP response body: {"error":"rate limit exceeded"}
#
#
# 3225623991
# 3219270582
# (862, 35)
# (28282, 35)
# 3217040638
# 3066599461
# 3064641857
# 3062347426
# 3060335733
# 3057893021
# 3053793520
# 3052273459
# 3051075730
# 3049880539
# 3049326595
# 3048569543
# (999, 35)
# (31194, 35)
# 3047493774
# 3046858029
# 3046015992
# 3042573082
# 3037055297
# 3032403618
# 2969911461
# 2960389310
# 2951193198
# 2943125010
# (999, 35)
# (32193, 35)
# 2936647834
# 2933526360
# 2930456403
# 2927454818
# 2925051596
# 2910435170
# 2909257353
# 2901935479
# 2896477872
# 2890672917
# 2882663618
# 2877435617
# 2873217217
# 2863938550
# 2859436941
# 2855630123
# 2853884605
# (999, 35)
# (33192, 35)
# 2849873307
# 2847753812
# 2845724914
# 2844863565
# 2842748086
# 2821569825
# 2818317471
# 2810415719
# 2806901200
# 2804128328
# 2801642000
# 2796947058

# %%
df_pro_first_half.head()

# %%
df_pro_first_half.to_csv("professional_raw_match_first_half_full.csv")
df_pro_first_half_1000 = df_pro_first_half.sample(1000)
df_pro_first_half_1000.to_csv("professional_raw_match_first_half_1000.csv")
df_pro_first_half_100 = df_pro_first_half.sample(100)
df_pro_first_half_1000.to_csv("professional_raw_match_first_half_100.csv")

# %% [markdown]
# # --------------------------------------------------------
